# %%
#@save
import collections
import hashlib
import math
import os
import random
import re
import shutil
import sys
import tarfile
import time
import zipfile
from collections import defaultdict
import pandas as pd
import requests
from IPython import display
from matplotlib import pyplot as plt
from matplotlib_inline import backend_inline

d2l = sys.modules[__name__]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 17
#      15 import requests
#      16 from IPython import display
# ---> 17 from matplotlib import pyplot as plt
#      18 from matplotlib_inline import backend_inline
#      20 d2l = sys.modules[__name__]
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
conda install matplotlib
# Out:
# /iridisfs/ixsoftware/conda/miniconda-py3/lib/python3.12/site-packages/conda/base/context.py:202: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /iridisfs/ixsoftware/conda/miniconda-py3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2025.1.31          |  py312h06a4308_0         162 KB
#     contourpy-1.3.1            |  py312hdb19cb5_0         276 KB
#     cycler-0.11.0              |     pyhd3eb1b0_0          12 KB
#     cyrus-sasl-2.1.28          |       h52b45da_1         237 KB
#     dbus-1.13.18               |       hb2f20db_0         504 KB
#     fontconfig-2.14.1          |       h55d465d_3         281 KB
#     fonttools-4.55.3           |  py312h5eee18b_0         2.9 MB
#     freetype-2.12.1            |       h4a9f257_0         626 KB
#     glib-2.78.4                |       h6a678d5_0         508 KB
#     glib-tools-2.78.4          |       h6a678d5_0         115 KB
#     gst-plugins-base-1.14.1    |       h6a678d5_1         2.2 MB
#     gstreamer-1.14.1           |       h5eee18b_1         1.7 MB
#     jpeg-9e                    |       h5eee18b_3         262 KB
#     kiwisolver-1.4.8           |  py312h6a678d5_0          69 KB
#     lcms2-2.16                 |       hb9589c4_0         269 KB
#     lerc-4.0.0                 |       h6a678d5_0         261 KB
#     libabseil-20240116.2       | cxx17_h6a678d5_0         1.3 MB
#     libclang-14.0.6            |default_hc6dbbc7_2         137 KB
#     libclang13-14.0.6          |default_he11475f_2         9.7 MB
#     libcups-2.4.2              |       h2d74bed_1         4.5 MB
#     libdeflate-1.22            |       h5eee18b_0          68 KB
#     libglib-2.78.4             |       hdc74915_0         1.5 MB
#     libiconv-1.16              |       h5eee18b_3         759 KB
#     libllvm14-14.0.6           |       hecde1de_4        33.4 MB
#     libpng-1.6.39              |       h5eee18b_0         304 KB
#     libpq-17.2                 |       hdbd6064_0         2.8 MB
#     libprotobuf-4.25.3         |       he621ea3_0         2.8 MB
#     libtiff-4.5.1              |       hffd6297_1         534 KB
#     libwebp-base-1.3.2         |       h5eee18b_1         425 KB
#     libxcb-1.15                |       h7f8727e_0         505 KB
#     libxkbcommon-1.0.1         |       h097e994_2         590 KB
#     matplotlib-3.10.0          |  py312h06a4308_0           7 KB
#     matplotlib-base-3.10.0     |  py312hbfdbfaf_0         8.2 MB
#     mysql-8.4.0                |       h29a9f33_1        56.6 MB
#     openjpeg-2.5.2             |       he7f1fd0_0         371 KB
#     openldap-2.6.4             |       h42fbc30_0         804 KB
#     pillow-11.1.0              |  py312hcea889d_0         958 KB
#     ply-3.11                   |  py312h06a4308_1         109 KB
#     pyparsing-3.2.0            |  py312h06a4308_0         471 KB
#     pyqt-5.15.10               |  py312h6a678d5_1         5.7 MB
#     pyqt5-sip-12.13.0          |  py312h5eee18b_1          96 KB
#     qt-main-5.15.2             |      hb6262e9_12        53.7 MB
#     sip-6.7.12                 |  py312h6a678d5_1         598 KB
#     tornado-6.4.2              |  py312h5eee18b_0         848 KB
#     unicodedata2-15.1.0        |  py312h5eee18b_1         524 KB
#     ------------------------------------------------------------
#                                            Total:       198.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   contourpy          pkgs/main/linux-64::contourpy-1.3.1-py312hdb19cb5_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   cyrus-sasl         pkgs/main/linux-64::cyrus-sasl-2.1.28-h52b45da_1
#   dbus               pkgs/main/linux-64::dbus-1.13.18-hb2f20db_0
#   fontconfig         pkgs/main/linux-64::fontconfig-2.14.1-h55d465d_3
#   fonttools          pkgs/main/linux-64::fonttools-4.55.3-py312h5eee18b_0
#   freetype           pkgs/main/linux-64::freetype-2.12.1-h4a9f257_0
#   glib               pkgs/main/linux-64::glib-2.78.4-h6a678d5_0
#   glib-tools         pkgs/main/linux-64::glib-tools-2.78.4-h6a678d5_0
#   gst-plugins-base   pkgs/main/linux-64::gst-plugins-base-1.14.1-h6a678d5_1
#   gstreamer          pkgs/main/linux-64::gstreamer-1.14.1-h5eee18b_1
#   jpeg               pkgs/main/linux-64::jpeg-9e-h5eee18b_3
#   kiwisolver         pkgs/main/linux-64::kiwisolver-1.4.8-py312h6a678d5_0
#   lcms2              pkgs/main/linux-64::lcms2-2.16-hb9589c4_0
#   lerc               pkgs/main/linux-64::lerc-4.0.0-h6a678d5_0
#   libabseil          pkgs/main/linux-64::libabseil-20240116.2-cxx17_h6a678d5_0
#   libclang           pkgs/main/linux-64::libclang-14.0.6-default_hc6dbbc7_2
#   libclang13         pkgs/main/linux-64::libclang13-14.0.6-default_he11475f_2
#   libcups            pkgs/main/linux-64::libcups-2.4.2-h2d74bed_1
#   libdeflate         pkgs/main/linux-64::libdeflate-1.22-h5eee18b_0
#   libglib            pkgs/main/linux-64::libglib-2.78.4-hdc74915_0
#   libiconv           pkgs/main/linux-64::libiconv-1.16-h5eee18b_3
#   libllvm14          pkgs/main/linux-64::libllvm14-14.0.6-hecde1de_4
#   libpng             pkgs/main/linux-64::libpng-1.6.39-h5eee18b_0
#   libpq              pkgs/main/linux-64::libpq-17.2-hdbd6064_0
#   libprotobuf        pkgs/main/linux-64::libprotobuf-4.25.3-he621ea3_0
#   libtiff            pkgs/main/linux-64::libtiff-4.5.1-hffd6297_1
#   libwebp-base       pkgs/main/linux-64::libwebp-base-1.3.2-h5eee18b_1
#   libxcb             pkgs/main/linux-64::libxcb-1.15-h7f8727e_0
#   libxkbcommon       pkgs/main/linux-64::libxkbcommon-1.0.1-h097e994_2
#   matplotlib         pkgs/main/linux-64::matplotlib-3.10.0-py312h06a4308_0
#   matplotlib-base    pkgs/main/linux-64::matplotlib-base-3.10.0-py312hbfdbfaf_0
#   mysql              pkgs/main/linux-64::mysql-8.4.0-h29a9f33_1
#   openjpeg           pkgs/main/linux-64::openjpeg-2.5.2-he7f1fd0_0
#   openldap           pkgs/main/linux-64::openldap-2.6.4-h42fbc30_0
#   pillow             pkgs/main/linux-64::pillow-11.1.0-py312hcea889d_0
#   ply                pkgs/main/linux-64::ply-3.11-py312h06a4308_1
#   pyparsing          pkgs/main/linux-64::pyparsing-3.2.0-py312h06a4308_0
#   pyqt               pkgs/main/linux-64::pyqt-5.15.10-py312h6a678d5_1
#   pyqt5-sip          pkgs/main/linux-64::pyqt5-sip-12.13.0-py312h5eee18b_1
#   qt-main            pkgs/main/linux-64::qt-main-5.15.2-hb6262e9_12
#   sip                pkgs/main/linux-64::sip-6.7.12-py312h6a678d5_1
#   tornado            pkgs/main/linux-64::tornado-6.4.2-py312h5eee18b_0
#   unicodedata2       pkgs/main/linux-64::unicodedata2-15.1.0-py312h5eee18b_1
#
# The following packages will be UPDATED:
#
#   certifi                        2024.12.14-py312h06a4308_0 --> 2025.1.31-py312h06a4308_0
#
#
#
# Downloading and Extracting Packages:
# mysql-8.4.0          | 56.6 MB   |                                       |   0%
# qt-main-5.15.2       | 53.7 MB   |                                       |   0%
#
# libllvm14-14.0.6     | 33.4 MB   |                                       |   0%
#
#
# libclang13-14.0.6    | 9.7 MB    |                                       |   0%
#
#
#
# matplotlib-base-3.10 | 8.2 MB    |                                       |   0%
#
#
#
#
# pyqt-5.15.10         | 5.7 MB    |                                       |   0%
#
#
#
#
#
# libcups-2.4.2        | 4.5 MB    |                                       |   0%
#
#
#
#
#
#
# fonttools-4.55.3     | 2.9 MB    |                                       |   0%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# libpq-17.2           | 2.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# gst-plugins-base-1.1 | 2.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# gstreamer-1.14.1     | 1.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.78.4       | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.1.0        | 958 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.4.2        | 848 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openldap-2.6.4       | 804 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.16        | 759 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 626 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 598 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxkbcommon-1.0.1   | 590 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 534 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 524 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libllvm14-14.0.6     | 33.4 MB   |                                       |   0%
#
#
# libclang13-14.0.6    | 9.7 MB    | 2                                     |   1%
# mysql-8.4.0          | 56.6 MB   |                                       |   0%
#
#
#
# matplotlib-base-3.10 | 8.2 MB    |                                       |   0%
#
# libllvm14-14.0.6     | 33.4 MB   | #2                                    |   3%
#
#
# libclang13-14.0.6    | 9.7 MB    | #####6                                |  15%
# mysql-8.4.0          | 56.6 MB   | 5                                     |   1%
#
#
#
# matplotlib-base-3.10 | 8.2 MB    | #9                                    |   5%
#
# libllvm14-14.0.6     | 33.4 MB   | ##1                                   |   6%
#
#
# libclang13-14.0.6    | 9.7 MB    | #########3                            |  25%
# mysql-8.4.0          | 56.6 MB   | 9                                     |   3%
#
#
#
# matplotlib-base-3.10 | 8.2 MB    | ######6                               |  18%
#
# libllvm14-14.0.6     | 33.4 MB   | ###1                                  |   9%
#
#
# libclang13-14.0.6    | 9.7 MB    | #############1                        |  36%
# mysql-8.4.0          | 56.6 MB   | #6                                    |   5%
#
#
#
# matplotlib-base-3.10 | 8.2 MB    | ##########9                           |  30%
#
# libllvm14-14.0.6     | 33.4 MB   | ####3                                 |  12%
#
#
# libclang13-14.0.6    | 9.7 MB    | #################9                    |  49%
# mysql-8.4.0          | 56.6 MB   | ##4                                   |   7%
#
#
#
# matplotlib-base-3.10 | 8.2 MB    | ###############2                      |  41%
#
# libllvm14-14.0.6     | 33.4 MB   | #####4                                |  15%
#
#
# libclang13-14.0.6    | 9.7 MB    | ######################5               |  61%
# mysql-8.4.0          | 56.6 MB   | ###6                                  |  10%
#
#
#
# matplotlib-base-3.10 | 8.2 MB    | ###################                   |  51%
#
#
# libclang13-14.0.6    | 9.7 MB    | ###########################3          |  74%
#
# mysql-8.4.0          | 56.6 MB   | ####5                                 |  12%
# qt-main-5.15.2       | 53.7 MB   | ###8                                  |  11%
#
#
#
# matplotlib-base-3.10 | 8.2 MB    | ######################6               |  61%
#
# libllvm14-14.0.6     | 33.4 MB   | ########3                             |  23%
#
#
# libclang13-14.0.6    | 9.7 MB    | ###############################7      |  86%
# mysql-8.4.0          | 56.6 MB   | #####5                                |  15%
#
#
#
# matplotlib-base-3.10 | 8.2 MB    | ###########################8          |  75%
#
# mysql-8.4.0          | 56.6 MB   | ######3                               |  17%
# qt-main-5.15.2       | 53.7 MB   | #####4                                |  15%
#
#
#
# matplotlib-base-3.10 | 8.2 MB    | ###############################9      |  86%
#
# mysql-8.4.0          | 56.6 MB   | #######5                              |  20%
# qt-main-5.15.2       | 53.7 MB   | ######2                               |  17%
#
#
#
# matplotlib-base-3.10 | 8.2 MB    | ####################################2 |  98%
#
# mysql-8.4.0          | 56.6 MB   | ########6                             |  23%
# qt-main-5.15.2       | 53.7 MB   | #######3                              |  20%
#
# mysql-8.4.0          | 56.6 MB   | ##########                            |  27%
# qt-main-5.15.2       | 53.7 MB   | ########3                             |  23%
#
# mysql-8.4.0          | 56.6 MB   | ###########3                          |  31%
# qt-main-5.15.2       | 53.7 MB   | #########5                            |  26%
#
# mysql-8.4.0          | 56.6 MB   | ############7                         |  34%
# qt-main-5.15.2       | 53.7 MB   | ##########4                           |  28%
#
# mysql-8.4.0          | 56.6 MB   | ##############1                       |  38%
# qt-main-5.15.2       | 53.7 MB   | ###########5                          |  31%
#
#
# libclang13-14.0.6    | 9.7 MB    | ##################################### | 100%
#
#
# libclang13-14.0.6    | 9.7 MB    | ##################################### | 100%
#
# mysql-8.4.0          | 56.6 MB   | ###############5                      |  42%
#
#
#
# matplotlib-base-3.10 | 8.2 MB    | ##################################### | 100%
# qt-main-5.15.2       | 53.7 MB   | ############5                         |  34%
#
#
#
#
# pyqt-5.15.10         | 5.7 MB    | 1                                     |   0%
#
#
#
#
#
# libcups-2.4.2        | 4.5 MB    | 1                                     |   0%
#
# mysql-8.4.0          | 56.6 MB   | ################8                     |  45%
#
#
#
#
# pyqt-5.15.10         | 5.7 MB    | ######3                               |  17%
#
#
#
#
#
# libcups-2.4.2        | 4.5 MB    | #######2                              |  20%
# qt-main-5.15.2       | 53.7 MB   | #############4                        |  36%
#
#
#
#
# pyqt-5.15.10         | 5.7 MB    | ###############5                      |  42%
#
# libllvm14-14.0.6     | 33.4 MB   | ########################4             |  66%
#
#
#
#
#
# mysql-8.4.0          | 56.6 MB   | ##################                    |  49%
# qt-main-5.15.2       | 53.7 MB   | ##############2                       |  39%
#
#
#
#
# pyqt-5.15.10         | 5.7 MB    | #######################6              |  64%
#
# libllvm14-14.0.6     | 33.4 MB   | #########################8            |  70%
#
#
#
#
#
# libcups-2.4.2        | 4.5 MB    | #######################4              |  63%
# mysql-8.4.0          | 56.6 MB   | ###################                   |  52%
#
#
#
#
# pyqt-5.15.10         | 5.7 MB    | ##############################5       |  83%
#
#
#
#
#
# libcups-2.4.2        | 4.5 MB    | ###############################       |  84%
#
# mysql-8.4.0          | 56.6 MB   | ####################                  |  54%
# qt-main-5.15.2       | 53.7 MB   | ###############8                      |  43%
#
# mysql-8.4.0          | 56.6 MB   | ####################9                 |  57%
# qt-main-5.15.2       | 53.7 MB   | ################7                     |  45%
#
# mysql-8.4.0          | 56.6 MB   | ######################                |  60%
# qt-main-5.15.2       | 53.7 MB   | #################5                    |  47%
#
# mysql-8.4.0          | 56.6 MB   | ######################9               |  62%
#
#
#
#
#
# libcups-2.4.2        | 4.5 MB    | ##################################### | 100%
# qt-main-5.15.2       | 53.7 MB   | ##################2                   |  49%
#
# libllvm14-14.0.6     | 33.4 MB   | #################################3    |  90%
#
#
#
#
#
#
# mysql-8.4.0          | 56.6 MB   | #######################9              |  65%
# qt-main-5.15.2       | 53.7 MB   | ###################                   |  52%
#
# libllvm14-14.0.6     | 33.4 MB   | ###################################   |  95%
#
#
#
#
#
#
# fonttools-4.55.3     | 2.9 MB    | #############5                        |  37%
#
#
#
#
# pyqt-5.15.10         | 5.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | 2                                     |   1%
#
# libllvm14-14.0.6     | 33.4 MB   | ####################################6 |  99%
# mysql-8.4.0          | 56.6 MB   | ########################8             |  67%
#
#
#
#
#
#
# fonttools-4.55.3     | 2.9 MB    | ##########################5           |  72%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ###############4                      |  42%
# mysql-8.4.0          | 56.6 MB   | #########################6            |  69%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ###############################5      |  85%
# mysql-8.4.0          | 56.6 MB   | ##########################4           |  72%
# qt-main-5.15.2       | 53.7 MB   | ######################3               |  60%
#
#
#
#
#
#
# fonttools-4.55.3     | 2.9 MB    | ##################################### | 100%
#
#
#
#
#
#
# mysql-8.4.0          | 56.6 MB   | ###########################7          |  75%
#
#
#
#
#
#
#
#
# libpq-17.2           | 2.8 MB    | 2                                     |   1%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ##################################### | 100%
# qt-main-5.15.2       | 53.7 MB   | #######################4              |  63%
#
#
#
#
#
#
#
#
#
# mysql-8.4.0          | 56.6 MB   | ############################6         |  77%
#
#
#
#
#
#
#
#
# libpq-17.2           | 2.8 MB    | ##################4                   |  50%
#
#
#
#
#
#
#
#
#
# gst-plugins-base-1.1 | 2.2 MB    | ########################7             |  67%
# mysql-8.4.0          | 56.6 MB   | #############################5        |  80%
# mysql-8.4.0          | 56.6 MB   | ##############################5       |  83%
# mysql-8.4.0          | 56.6 MB   | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
# gst-plugins-base-1.1 | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libpq-17.2           | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libpq-17.2           | 2.8 MB    | ##################################### | 100%
# qt-main-5.15.2       | 53.7 MB   | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
#
# mysql-8.4.0          | 56.6 MB   | ################################4     |  88%
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.78.4       | 1.5 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
# gstreamer-1.14.1     | 1.7 MB    | ##############################9       |  84%
# qt-main-5.15.2       | 53.7 MB   | ############################          |  76%
#
#
#
#
#
#
#
#
#
#
#
# mysql-8.4.0          | 56.6 MB   | #################################4    |  90%
# qt-main-5.15.2       | 53.7 MB   | #############################         |  79%
#
#
#
#
#
#
#
#
#
#
# gstreamer-1.14.1     | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# mysql-8.4.0          | 56.6 MB   | ##################################2   |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.1.0        | 958 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | 4                                     |   1%
# qt-main-5.15.2       | 53.7 MB   | ##############################        |  81%
#
#
# mysql-8.4.0          | 56.6 MB   | ###################################1  |  95%
# qt-main-5.15.2       | 53.7 MB   | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.1.0        | 958 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-8.4.0          | 56.6 MB   | ####################################4 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.4.2        | 848 KB    | 6                                     |   2%
#
#
#
#
#
# libcups-2.4.2        | 4.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openldap-2.6.4       | 804 KB    | 7                                     |   2%
# qt-main-5.15.2       | 53.7 MB   | ################################5     |  88%
# qt-main-5.15.2       | 53.7 MB   | #################################7    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.4.2        | 848 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.4.2        | 848 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openldap-2.6.4       | 804 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openldap-2.6.4       | 804 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.16        | 759 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 626 KB    | 9                                     |   3%
# qt-main-5.15.2       | 53.7 MB   | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 626 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.16        | 759 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.16        | 759 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 598 KB    | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxkbcommon-1.0.1   | 590 KB    | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxkbcommon-1.0.1   | 590 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 598 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 534 KB    | #1                                    |   3%
#
# libllvm14-14.0.6     | 33.4 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 534 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 524 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 524 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-8.4.0          | 56.6 MB   | ##################################### | 100% [A
# qt-main-5.15.2       | 53.7 MB   | ##################################### | 100%
# qt-main-5.15.2       | 53.7 MB   | ##################################### | 100%
#
#
#
#
#
#
# fonttools-4.55.3     | 2.9 MB    | ##################################### | 100%
#
#
#
# matplotlib-base-3.10 | 8.2 MB    | ##################################### | 100%
#
#
#
#
# pyqt-5.15.10         | 5.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# libprotobuf-4.25.3   | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# gst-plugins-base-1.1 | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libglib-2.78.4       | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# gstreamer-1.14.1     | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.1.0        | 958 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tornado-6.4.2        | 848 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libpq-17.2           | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libabseil-20240116.2 | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 626 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.12.1      | 626 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxkbcommon-1.0.1   | 590 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxkbcommon-1.0.1   | 590 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openldap-2.6.4       | 804 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libiconv-1.16        | 759 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 534 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.5.1        | 534 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 524 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 524 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 598 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sip-6.7.12           | 598 KB    | ##################################### | 100%
#
# libllvm14-14.0.6     | 33.4 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-8.4.0          | 56.6 MB   | ##################################### | 100% [A
# qt-main-5.15.2       | 53.7 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: failed
#
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: /iridisfs/ixsoftware/conda/miniconda-py3
#   uid: 49537
#   gid: 245
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda env list
# Out:
# /iridisfs/ixsoftware/conda/miniconda-py3/lib/python3.12/site-packages/conda/base/context.py:202: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
#
# # conda environments:
# #
# shuyanenv              /home/sz1c24/.conda/envs/shuyanenv
# base                 * /iridisfs/ixsoftware/conda/miniconda-py3
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda activate shuyanenv
# Out:
# CondaError: Run 'conda init' before 'conda activate'
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda init
# Out:
# no change     /iridisfs/ixsoftware/conda/miniconda-py3/condabin/conda
# no change     /iridisfs/ixsoftware/conda/miniconda-py3/bin/conda
# no change     /iridisfs/ixsoftware/conda/miniconda-py3/bin/conda-env
# no change     /iridisfs/ixsoftware/conda/miniconda-py3/bin/activate
# no change     /iridisfs/ixsoftware/conda/miniconda-py3/bin/deactivate
# no change     /iridisfs/ixsoftware/conda/miniconda-py3/etc/profile.d/conda.sh
# no change     /iridisfs/ixsoftware/conda/miniconda-py3/etc/fish/conf.d/conda.fish
# no change     /iridisfs/ixsoftware/conda/miniconda-py3/shell/condabin/Conda.psm1
# no change     /iridisfs/ixsoftware/conda/miniconda-py3/shell/condabin/conda-hook.ps1
# no change     /iridisfs/ixsoftware/conda/miniconda-py3/lib/python3.12/site-packages/xontrib/conda.xsh
# no change     /iridisfs/ixsoftware/conda/miniconda-py3/etc/profile.d/conda.csh
# no change     /home/sz1c24/.bashrc
# No action taken.
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda activate shuyanenv
# Out:
# CondaError: Run 'conda init' before 'conda activate'
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda env list
# Out:
# /iridisfs/ixsoftware/conda/miniconda-py3/lib/python3.12/site-packages/conda/base/context.py:202: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
#
# # conda environments:
# #
# shuyanenv              /home/sz1c24/.conda/envs/shuyanenv
# base                 * /iridisfs/ixsoftware/conda/miniconda-py3
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
print("1")
# Out:
# 1

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
import sys
print(sys.executable)
# Out:
# /iridisfs/ixsoftware/conda/miniconda-py3/bin/python

# %%
conda activate shuyanenv
# Out:
# CondaError: Run 'conda init' before 'conda activate'
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
python -c "import torch; print(torch.__version__)"
# Out:
#   Cell In[8], line 1
#     python -c "import torch; print(torch.__version__)"
#               ^
# SyntaxError: invalid syntax

# %%
conda install pytorch torchvision torchaudio -c pytorch
# Out:
# /iridisfs/ixsoftware/conda/miniconda-py3/lib/python3.12/site-packages/conda/base/context.py:202: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - pytorch
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /iridisfs/ixsoftware/conda/miniconda-py3
#
#   added / updated specs:
#     - pytorch
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cuda-cudart-12.4.127       |       h99ab3db_0          21 KB
#     cuda-cudart_linux-64-12.4.127|       hd681fbe_0         207 KB
#     cuda-cupti-12.4.127        |       h6a678d5_1         2.0 MB
#     cuda-libraries-12.4.1      |       h06a4308_1          19 KB
#     cuda-nvrtc-12.4.127        |       h99ab3db_1        19.8 MB
#     cuda-nvtx-12.4.127         |       h6a678d5_1          30 KB
#     cuda-opencl-12.4.127       |       h6a678d5_0          28 KB
#     cuda-runtime-12.4.1        |       hb982923_0          18 KB
#     cuda-version-12.4          |       hbda6634_3          19 KB
#     ffmpeg-4.3                 |       hf484d3e_0         9.9 MB  pytorch
#     giflib-5.2.2               |       h5eee18b_0          80 KB
#     gmp-6.3.0                  |       h6a678d5_0         608 KB
#     gmpy2-2.2.1                |  py312h5eee18b_0         258 KB
#     gnutls-3.6.15              |       he1e5248_0         1.0 MB
#     jinja2-3.1.5               |  py312h06a4308_0         352 KB
#     lame-3.100                 |       h7b6447c_0         323 KB
#     libcublas-12.4.5.8         |       h99ab3db_1       247.6 MB
#     libcufft-11.2.1.3          |       h99ab3db_1       174.5 MB
#     libcufile-1.9.1.3          |       h99ab3db_1         995 KB
#     libcurand-10.3.5.147       |       h99ab3db_1        42.4 MB
#     libcusolver-11.6.1.9       |       h99ab3db_1        83.5 MB
#     libcusparse-12.3.1.170     |       h99ab3db_1       120.0 MB
#     libidn2-2.3.4              |       h5eee18b_0         146 KB
#     libjpeg-turbo-2.0.0        |       h9bf148f_0         950 KB  pytorch
#     libnpp-12.2.5.30           |       h99ab3db_1       100.5 MB
#     libnvfatbin-12.4.127       |       h7934f7d_2         857 KB
#     libnvjitlink-12.4.127      |       h99ab3db_1        17.4 MB
#     libnvjpeg-12.3.1.117       |       h6a678d5_1         2.6 MB
#     libtasn1-4.19.0            |       h5eee18b_0          63 KB
#     libunistring-0.9.10        |       h27cfd23_0         536 KB
#     libwebp-1.3.2              |       h11a3e52_0          87 KB
#     llvm-openmp-14.0.6         |       h9e868ea_0         4.4 MB
#     markupsafe-3.0.2           |  py312h5eee18b_0          26 KB
#     mpc-1.3.1                  |       h5eee18b_0         129 KB
#     mpfr-4.2.1                 |       h5eee18b_0         821 KB
#     nettle-3.7.3               |       hbbd107a_1         809 KB
#     networkx-3.4.2             |  py312h06a4308_0         3.1 MB
#     ocl-icd-2.3.2              |       h5eee18b_1         136 KB
#     openh264-2.1.1             |       h4ff587b_0         711 KB
#     pytorch-2.5.1              |py3.12_cuda12.4_cudnn9.1.0_0        1.46 GB  pytorch
#     pytorch-cuda-12.4          |       hc786d27_7           7 KB  pytorch
#     pytorch-mutex-1.0          |             cuda           3 KB  pytorch
#     pyyaml-6.0.2               |  py312h5eee18b_0         217 KB
#     sympy-1.13.3               |  py312h06a4308_1        15.0 MB
#     torchaudio-2.5.1           |      py312_cu124         6.3 MB  pytorch
#     torchtriton-3.1.0          |            py312       233.6 MB  pytorch
#     torchvision-0.20.1         |      py312_cu124         8.4 MB  pytorch
#     typing_extensions-4.12.2   |  py312h06a4308_0          79 KB
#     yaml-0.2.5                 |       h7b6447c_0          75 KB
#     ------------------------------------------------------------
#                                            Total:        2.54 GB
#
# The following NEW packages will be INSTALLED:
#
#   cuda-cudart        pkgs/main/linux-64::cuda-cudart-12.4.127-h99ab3db_0
#   cuda-cudart_linux~ pkgs/main/noarch::cuda-cudart_linux-64-12.4.127-hd681fbe_0
#   cuda-cupti         pkgs/main/linux-64::cuda-cupti-12.4.127-h6a678d5_1
#   cuda-libraries     pkgs/main/linux-64::cuda-libraries-12.4.1-h06a4308_1
#   cuda-nvrtc         pkgs/main/linux-64::cuda-nvrtc-12.4.127-h99ab3db_1
#   cuda-nvtx          pkgs/main/linux-64::cuda-nvtx-12.4.127-h6a678d5_1
#   cuda-opencl        pkgs/main/linux-64::cuda-opencl-12.4.127-h6a678d5_0
#   cuda-runtime       pkgs/main/noarch::cuda-runtime-12.4.1-hb982923_0
#   cuda-version       pkgs/main/noarch::cuda-version-12.4-hbda6634_3
#   ffmpeg             pytorch/linux-64::ffmpeg-4.3-hf484d3e_0
#   filelock           pkgs/main/linux-64::filelock-3.13.1-py312h06a4308_0
#   freetype           pkgs/main/linux-64::freetype-2.12.1-h4a9f257_0
#   giflib             pkgs/main/linux-64::giflib-5.2.2-h5eee18b_0
#   gmp                pkgs/main/linux-64::gmp-6.3.0-h6a678d5_0
#   gmpy2              pkgs/main/linux-64::gmpy2-2.2.1-py312h5eee18b_0
#   gnutls             pkgs/main/linux-64::gnutls-3.6.15-he1e5248_0
#   jinja2             pkgs/main/linux-64::jinja2-3.1.5-py312h06a4308_0
#   jpeg               pkgs/main/linux-64::jpeg-9e-h5eee18b_3
#   lame               pkgs/main/linux-64::lame-3.100-h7b6447c_0
#   lcms2              pkgs/main/linux-64::lcms2-2.16-hb9589c4_0
#   lerc               pkgs/main/linux-64::lerc-4.0.0-h6a678d5_0
#   libcublas          pkgs/main/linux-64::libcublas-12.4.5.8-h99ab3db_1
#   libcufft           pkgs/main/linux-64::libcufft-11.2.1.3-h99ab3db_1
#   libcufile          pkgs/main/linux-64::libcufile-1.9.1.3-h99ab3db_1
#   libcurand          pkgs/main/linux-64::libcurand-10.3.5.147-h99ab3db_1
#   libcusolver        pkgs/main/linux-64::libcusolver-11.6.1.9-h99ab3db_1
#   libcusparse        pkgs/main/linux-64::libcusparse-12.3.1.170-h99ab3db_1
#   libdeflate         pkgs/main/linux-64::libdeflate-1.22-h5eee18b_0
#   libiconv           pkgs/main/linux-64::libiconv-1.16-h5eee18b_3
#   libidn2            pkgs/main/linux-64::libidn2-2.3.4-h5eee18b_0
#   libjpeg-turbo      pytorch/linux-64::libjpeg-turbo-2.0.0-h9bf148f_0
#   libnpp             pkgs/main/linux-64::libnpp-12.2.5.30-h99ab3db_1
#   libnvfatbin        pkgs/main/linux-64::libnvfatbin-12.4.127-h7934f7d_2
#   libnvjitlink       pkgs/main/linux-64::libnvjitlink-12.4.127-h99ab3db_1
#   libnvjpeg          pkgs/main/linux-64::libnvjpeg-12.3.1.117-h6a678d5_1
#   libpng             pkgs/main/linux-64::libpng-1.6.39-h5eee18b_0
#   libtasn1           pkgs/main/linux-64::libtasn1-4.19.0-h5eee18b_0
#   libtiff            pkgs/main/linux-64::libtiff-4.5.1-hffd6297_1
#   libunistring       pkgs/main/linux-64::libunistring-0.9.10-h27cfd23_0
#   libwebp            pkgs/main/linux-64::libwebp-1.3.2-h11a3e52_0
#   libwebp-base       pkgs/main/linux-64::libwebp-base-1.3.2-h5eee18b_1
#   llvm-openmp        pkgs/main/linux-64::llvm-openmp-14.0.6-h9e868ea_0
#   markupsafe         pkgs/main/linux-64::markupsafe-3.0.2-py312h5eee18b_0
#   mpc                pkgs/main/linux-64::mpc-1.3.1-h5eee18b_0
#   mpfr               pkgs/main/linux-64::mpfr-4.2.1-h5eee18b_0
#   mpmath             pkgs/main/linux-64::mpmath-1.3.0-py312h06a4308_0
#   nettle             pkgs/main/linux-64::nettle-3.7.3-hbbd107a_1
#   networkx           pkgs/main/linux-64::networkx-3.4.2-py312h06a4308_0
#   ocl-icd            pkgs/main/linux-64::ocl-icd-2.3.2-h5eee18b_1
#   openh264           pkgs/main/linux-64::openh264-2.1.1-h4ff587b_0
#   openjpeg           pkgs/main/linux-64::openjpeg-2.5.2-he7f1fd0_0
#   pillow             pkgs/main/linux-64::pillow-11.1.0-py312hcea889d_0
#   pytorch            pytorch/linux-64::pytorch-2.5.1-py3.12_cuda12.4_cudnn9.1.0_0
#   pytorch-cuda       pytorch/linux-64::pytorch-cuda-12.4-hc786d27_7
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   pyyaml             pkgs/main/linux-64::pyyaml-6.0.2-py312h5eee18b_0
#   sympy              pkgs/main/linux-64::sympy-1.13.3-py312h06a4308_1
#   torchaudio         pytorch/linux-64::torchaudio-2.5.1-py312_cu124
#   torchtriton        pytorch/linux-64::torchtriton-3.1.0-py312
#   torchvision        pytorch/linux-64::torchvision-0.20.1-py312_cu124
#   typing_extensions  pkgs/main/linux-64::typing_extensions-4.12.2-py312h06a4308_0
#   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
#
# The following packages will be UPDATED:
#
#   certifi                        2024.12.14-py312h06a4308_0 --> 2025.1.31-py312h06a4308_0
#
#
#
# Downloading and Extracting Packages:
# pytorch-2.5.1        | 1.46 GB   |                                       |   0%
# libcublas-12.4.5.8   | 247.6 MB  |                                       |   0%
#
# torchtriton-3.1.0    | 233.6 MB  |                                       |   0%
#
#
# libcufft-11.2.1.3    | 174.5 MB  |                                       |   0%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  |                                       |   0%
#
#
#
#
# libnpp-12.2.5.30     | 100.5 MB  |                                       |   0%
#
#
#
#
#
# libcusolver-11.6.1.9 | 83.5 MB   |                                       |   0%
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   |                                       |   0%
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   |                                       |   0%
#
#
#
#
#
#
#
#
# libnvjitlink-12.4.12 | 17.4 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# sympy-1.13.3         | 15.0 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.1   | 8.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 6.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 3.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-12.3.1.117 | 2.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-cupti-12.4.127  | 2.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufile-1.9.1.3    | 995 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-2.0.0  | 950 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvfatbin-12.4.127 | 857 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 821 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libcublas-12.4.5.8   | 247.6 MB  |                                       |   0%
#
#
# pytorch-2.5.1        | 1.46 GB   |                                       |   0%
#
# torchtriton-3.1.0    | 233.6 MB  |                                       |   0%
# libcublas-12.4.5.8   | 247.6 MB  | 2                                     |   1%
#
#
# pytorch-2.5.1        | 1.46 GB   |                                       |   0%
#
# torchtriton-3.1.0    | 233.6 MB  | 1                                     |   1%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  |                                       |   0%
# libcublas-12.4.5.8   | 247.6 MB  | 4                                     |   1%
#
#
# pytorch-2.5.1        | 1.46 GB   |                                       |   0%
#
# torchtriton-3.1.0    | 233.6 MB  | 3                                     |   1%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | 1                                     |   0%
#
#
# pytorch-2.5.1        | 1.46 GB   |                                       |   0%
#
# torchtriton-3.1.0    | 233.6 MB  | 5                                     |   1%
# libcublas-12.4.5.8   | 247.6 MB  | 5                                     |   2%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | 4                                     |   1%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #1                                    |   3%
#
# pytorch-2.5.1        | 1.46 GB   | 1                                     |   0%
# libcublas-12.4.5.8   | 247.6 MB  | 7                                     |   2%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | 9                                     |   3%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #4                                    |   4%
#
# pytorch-2.5.1        | 1.46 GB   | 1                                     |   0%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | #2                                    |   3%
# libcublas-12.4.5.8   | 247.6 MB  | 8                                     |   2%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #6                                    |   5%
#
# pytorch-2.5.1        | 1.46 GB   | 1                                     |   0%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | #7                                    |   5%
# libcublas-12.4.5.8   | 247.6 MB  | 9                                     |   3%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##                                    |   6%
#
# pytorch-2.5.1        | 1.46 GB   | 2                                     |   1%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##1                                   |   6%
# libcublas-12.4.5.8   | 247.6 MB  | #1                                    |   3%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##3                                   |   6%
#
# pytorch-2.5.1        | 1.46 GB   | 2                                     |   1%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##5                                   |   7%
# libcublas-12.4.5.8   | 247.6 MB  | #2                                    |   3%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##6                                   |   7%
#
# pytorch-2.5.1        | 1.46 GB   | 2                                     |   1%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##8                                   |   8%
# libcublas-12.4.5.8   | 247.6 MB  | #4                                    |   4%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##8                                   |   8%
#
# torchtriton-3.1.0    | 233.6 MB  | #9                                    |   5%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 3                                     |   1%
# libcublas-12.4.5.8   | 247.6 MB  | #6                                    |   4%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###1                                  |   9%
#
# torchtriton-3.1.0    | 233.6 MB  | ##1                                   |   6%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 3                                     |   1%
# libcublas-12.4.5.8   | 247.6 MB  | #7                                    |   5%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###4                                  |   9%
#
# torchtriton-3.1.0    | 233.6 MB  | ##3                                   |   6%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 3                                     |   1%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###7                                  |  10%
# libcublas-12.4.5.8   | 247.6 MB  | #9                                    |   5%
#
# torchtriton-3.1.0    | 233.6 MB  | ##5                                   |   7%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 4                                     |   1%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ####                                  |  11%
# libcublas-12.4.5.8   | 247.6 MB  | ##                                    |   6%
#
# torchtriton-3.1.0    | 233.6 MB  | ##7                                   |   7%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 4                                     |   1%
# libcublas-12.4.5.8   | 247.6 MB  | ##2                                   |   6%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ####3                                 |  12%
#
# torchtriton-3.1.0    | 233.6 MB  | ##9                                   |   8%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 4                                     |   1%
# libcublas-12.4.5.8   | 247.6 MB  | ##4                                   |   7%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ####6                                 |  13%
#
# torchtriton-3.1.0    | 233.6 MB  | ###1                                  |   9%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 4                                     |   1%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ####9                                 |  13%
# libcublas-12.4.5.8   | 247.6 MB  | ##5                                   |   7%
#
# torchtriton-3.1.0    | 233.6 MB  | ###3                                  |   9%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 5                                     |   1%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #####2                                |  14%
# libcublas-12.4.5.8   | 247.6 MB  | ##7                                   |   7%
#
# torchtriton-3.1.0    | 233.6 MB  | ###5                                  |  10%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 5                                     |   2%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #####5                                |  15%
# libcublas-12.4.5.8   | 247.6 MB  | ##8                                   |   8%
#
# torchtriton-3.1.0    | 233.6 MB  | ###7                                  |  10%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 5                                     |   2%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #####7                                |  16%
#
# torchtriton-3.1.0    | 233.6 MB  | ###9                                  |  11%
# libcublas-12.4.5.8   | 247.6 MB  | ###                                   |   8%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 6                                     |   2%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ######                                |  16%
# libcublas-12.4.5.8   | 247.6 MB  | ###1                                  |   9%
#
# torchtriton-3.1.0    | 233.6 MB  | ####1                                 |  11%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 6                                     |   2%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ######3                               |  17%
#
# torchtriton-3.1.0    | 233.6 MB  | ####3                                 |  12%
# libcublas-12.4.5.8   | 247.6 MB  | ###3                                  |   9%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 6                                     |   2%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ######6                               |  18%
#
# torchtriton-3.1.0    | 233.6 MB  | ####5                                 |  12%
# libcublas-12.4.5.8   | 247.6 MB  | ###4                                  |   9%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 7                                     |   2%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ######9                               |  19%
#
# torchtriton-3.1.0    | 233.6 MB  | ####6                                 |  13%
# libcublas-12.4.5.8   | 247.6 MB  | ###6                                  |  10%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ########8                             |  24%
#
#
# pytorch-2.5.1        | 1.46 GB   | 7                                     |   2%
#
# torchtriton-3.1.0    | 233.6 MB  | ####8                                 |  13%
# libcublas-12.4.5.8   | 247.6 MB  | ###8                                  |  10%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | #########1                            |  25%
#
#
# pytorch-2.5.1        | 1.46 GB   | 7                                     |   2%
#
# torchtriton-3.1.0    | 233.6 MB  | #####                                 |  14%
# libcublas-12.4.5.8   | 247.6 MB  | ####                                  |  11%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 8                                     |   2%
#
# torchtriton-3.1.0    | 233.6 MB  | #####3                                |  14%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #######7                              |  21%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##########                            |  27%
# pytorch-2.5.1        | 1.46 GB   | 8                                     |   2%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ########                              |  22%
#
# torchtriton-3.1.0    | 233.6 MB  | #####5                                |  15%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##########5                           |  28%
# pytorch-2.5.1        | 1.46 GB   | 8                                     |   2%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ########3                             |  23%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##########9                           |  30%
#
# torchtriton-3.1.0    | 233.6 MB  | #####7                                |  16%
# pytorch-2.5.1        | 1.46 GB   | 9                                     |   2%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ########6                             |  23%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ###########4                          |  31%
#
# torchtriton-3.1.0    | 233.6 MB  | #####9                                |  16%
# libcublas-12.4.5.8   | 247.6 MB  | ####6                                 |  13%
#
#
# pytorch-2.5.1        | 1.46 GB   | 9                                     |   3%
#
# torchtriton-3.1.0    | 233.6 MB  | ######1                               |  17%
# libcublas-12.4.5.8   | 247.6 MB  | ####8                                 |  13%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | 9                                     |   3%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #########2                            |  25%
#
# torchtriton-3.1.0    | 233.6 MB  | ######3                               |  17%
# libcublas-12.4.5.8   | 247.6 MB  | #####1                                |  14%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #                                     |   3%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #########5                            |  26%
#
# torchtriton-3.1.0    | 233.6 MB  | ######5                               |  18%
# pytorch-2.5.1        | 1.46 GB   | #                                     |   3%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #########8                            |  27%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ############7                         |  34%
#
# torchtriton-3.1.0    | 233.6 MB  | ######7                               |  18%
# libcublas-12.4.5.8   | 247.6 MB  | #####4                                |  15%
#
#
# pytorch-2.5.1        | 1.46 GB   | #                                     |   3%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | #############1                        |  35%
#
# torchtriton-3.1.0    | 233.6 MB  | #######                               |  19%
# libcublas-12.4.5.8   | 247.6 MB  | #####7                                |  16%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##########5                           |  28%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #1                                    |   3%
# libcublas-12.4.5.8   | 247.6 MB  | #####9                                |  16%
#
# torchtriton-3.1.0    | 233.6 MB  | #######2                              |  19%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##########8                           |  29%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##############                        |  38%
#
# torchtriton-3.1.0    | 233.6 MB  | #######4                              |  20%
# pytorch-2.5.1        | 1.46 GB   | #1                                    |   3%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##############4                       |  39%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###########1                          |  30%
#
# torchtriton-3.1.0    | 233.6 MB  | #######6                              |  21%
# pytorch-2.5.1        | 1.46 GB   | #1                                    |   3%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##############8                       |  40%
# libcublas-12.4.5.8   | 247.6 MB  | ######5                               |  18%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###########4                          |  31%
#
# pytorch-2.5.1        | 1.46 GB   | #1                                    |   3%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ###############2                      |  41%
# pytorch-2.5.1        | 1.46 GB   | #2                                    |   3%
#
# torchtriton-3.1.0    | 233.6 MB  | ########                              |  22%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###########6                          |  32%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #2                                    |   3%
#
# torchtriton-3.1.0    | 233.6 MB  | ########1                             |  22%
# libcublas-12.4.5.8   | 247.6 MB  | ######9                               |  19%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###########9                          |  32%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #2                                    |   4%
#
# torchtriton-3.1.0    | 233.6 MB  | ########3                             |  23%
# libcublas-12.4.5.8   | 247.6 MB  | #######2                              |  20%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ############1                         |  33%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ################4                     |  45%
#
# pytorch-2.5.1        | 1.46 GB   | #3                                    |   4%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ############4                         |  34%
# libcublas-12.4.5.8   | 247.6 MB  | #######4                              |  20%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #3                                    |   4%
#
# torchtriton-3.1.0    | 233.6 MB  | ########7                             |  24%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ############6                         |  34%
# libcublas-12.4.5.8   | 247.6 MB  | #######6                              |  21%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | #################4                    |  47%
#
# torchtriton-3.1.0    | 233.6 MB  | ########9                             |  24%
#
#
# pytorch-2.5.1        | 1.46 GB   | #3                                    |   4%
# libcublas-12.4.5.8   | 247.6 MB  | #######8                              |  21%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | #################8                    |  48%
#
# torchtriton-3.1.0    | 233.6 MB  | #########2                            |  25%
#
#
# pytorch-2.5.1        | 1.46 GB   | #4                                    |   4%
# libcublas-12.4.5.8   | 247.6 MB  | ########                              |  22%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##################2                   |  49%
#
# torchtriton-3.1.0    | 233.6 MB  | #########4                            |  25%
#
#
# pytorch-2.5.1        | 1.46 GB   | #4                                    |   4%
# libcublas-12.4.5.8   | 247.6 MB  | ########2                             |  22%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##################7                   |  51%
#
# torchtriton-3.1.0    | 233.6 MB  | #########6                            |  26%
#
#
# pytorch-2.5.1        | 1.46 GB   | #4                                    |   4%
# libcublas-12.4.5.8   | 247.6 MB  | ########4                             |  23%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ###################2                  |  52%
#
# torchtriton-3.1.0    | 233.6 MB  | #########8                            |  27%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##############2                       |  38%
# pytorch-2.5.1        | 1.46 GB   | #5                                    |   4%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ###################6                  |  53%
#
# torchtriton-3.1.0    | 233.6 MB  | ##########                            |  27%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##############5                       |  39%
# pytorch-2.5.1        | 1.46 GB   | #5                                    |   4%
#
# torchtriton-3.1.0    | 233.6 MB  | ##########2                           |  28%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ####################                  |  54%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##############8                       |  40%
# pytorch-2.5.1        | 1.46 GB   | #5                                    |   4%
#
# torchtriton-3.1.0    | 233.6 MB  | ##########4                           |  28%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ####################5                 |  56%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###############1                      |  41%
# pytorch-2.5.1        | 1.46 GB   | #5                                    |   4%
#
# torchtriton-3.1.0    | 233.6 MB  | ##########7                           |  29%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ####################9                 |  57%
# libcublas-12.4.5.8   | 247.6 MB  | #########5                            |  26%
#
#
# pytorch-2.5.1        | 1.46 GB   | #6                                    |   4%
#
# torchtriton-3.1.0    | 233.6 MB  | ##########9                           |  30%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | #####################4                |  58%
# libcublas-12.4.5.8   | 247.6 MB  | #########7                            |  26%
#
#
# pytorch-2.5.1        | 1.46 GB   | #6                                    |   4%
#
# torchtriton-3.1.0    | 233.6 MB  | ###########1                          |  30%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | #####################8                |  59%
# libcublas-12.4.5.8   | 247.6 MB  | ##########                            |  27%
#
#
# pytorch-2.5.1        | 1.46 GB   | #6                                    |   5%
#
# torchtriton-3.1.0    | 233.6 MB  | ###########3                          |  31%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ######################3               |  60%
# libcublas-12.4.5.8   | 247.6 MB  | ##########2                           |  28%
#
#
# pytorch-2.5.1        | 1.46 GB   | #7                                    |   5%
#
# torchtriton-3.1.0    | 233.6 MB  | ###########5                          |  31%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ######################7               |  61%
#
#
# pytorch-2.5.1        | 1.46 GB   | #7                                    |   5%
# libcublas-12.4.5.8   | 247.6 MB  | ##########4                           |  28%
#
# torchtriton-3.1.0    | 233.6 MB  | ###########8                          |  32%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | #######################1              |  63%
#
#
# pytorch-2.5.1        | 1.46 GB   | #7                                    |   5%
# libcublas-12.4.5.8   | 247.6 MB  | ##########6                           |  29%
#
# torchtriton-3.1.0    | 233.6 MB  | ############                          |  32%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #################5                    |  47%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #8                                    |   5%
# libcublas-12.4.5.8   | 247.6 MB  | ##########8                           |  29%
#
# torchtriton-3.1.0    | 233.6 MB  | ############2                         |  33%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ########################              |  65%
#
#
# pytorch-2.5.1        | 1.46 GB   | #8                                    |   5%
# libcublas-12.4.5.8   | 247.6 MB  | ###########                           |  30%
#
# torchtriton-3.1.0    | 233.6 MB  | ############4                         |  34%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ########################4             |  66%
#
#
# pytorch-2.5.1        | 1.46 GB   | #8                                    |   5%
# libcublas-12.4.5.8   | 247.6 MB  | ###########2                          |  30%
#
# torchtriton-3.1.0    | 233.6 MB  | ############6                         |  34%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ########################9             |  67%
#
#
# pytorch-2.5.1        | 1.46 GB   | #9                                    |   5%
# libcublas-12.4.5.8   | 247.6 MB  | ###########4                          |  31%
#
# torchtriton-3.1.0    | 233.6 MB  | ############8                         |  35%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | #########################3            |  68%
#
#
# pytorch-2.5.1        | 1.46 GB   | #9                                    |   5%
# libcublas-12.4.5.8   | 247.6 MB  | ###########7                          |  32%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | #########################7            |  70%
#
# torchtriton-3.1.0    | 233.6 MB  | #############                         |  35%
#
#
# pytorch-2.5.1        | 1.46 GB   | #9                                    |   5%
# libcublas-12.4.5.8   | 247.6 MB  | ###########9                          |  32%
#
# pytorch-2.5.1        | 1.46 GB   | ##                                    |   6%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###################4                  |  53%
# libcublas-12.4.5.8   | 247.6 MB  | ############1                         |  33%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##########################1           |  71%
#
# torchtriton-3.1.0    | 233.6 MB  | #############3                        |  36%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###################7                  |  53%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##                                    |   6%
# libcublas-12.4.5.8   | 247.6 MB  | ############3                         |  33%
#
# torchtriton-3.1.0    | 233.6 MB  | #############6                        |  37%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##########################9           |  73%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ####################                  |  54%
# pytorch-2.5.1        | 1.46 GB   | ##1                                   |   6%
#
# torchtriton-3.1.0    | 233.6 MB  | #############8                        |  37%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ###########################3          |  74%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ####################3                 |  55%
# pytorch-2.5.1        | 1.46 GB   | ##1                                   |   6%
#
# torchtriton-3.1.0    | 233.6 MB  | ##############                        |  38%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ####################7                 |  56%
# libcublas-12.4.5.8   | 247.6 MB  | #############                         |  35%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##1                                   |   6%
#
# torchtriton-3.1.0    | 233.6 MB  | ##############2                       |  38%
# libcublas-12.4.5.8   | 247.6 MB  | #############2                        |  36%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ############################1         |  76%
#
#
# pytorch-2.5.1        | 1.46 GB   | ##2                                   |   6%
#
# torchtriton-3.1.0    | 233.6 MB  | ##############4                       |  39%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #####################2                |  58%
# libcublas-12.4.5.8   | 247.6 MB  | #############4                        |  36%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##2                                   |   6%
#
# torchtriton-3.1.0    | 233.6 MB  | ##############6                       |  40%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #####################5                |  58%
# pytorch-2.5.1        | 1.46 GB   | ##2                                   |   6%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ############################9         |  78%
#
# torchtriton-3.1.0    | 233.6 MB  | ##############8                       |  40%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #####################9                |  59%
# libcublas-12.4.5.8   | 247.6 MB  | #############8                        |  38%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##3                                   |   6%
#
# torchtriton-3.1.0    | 233.6 MB  | ###############                       |  41%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ######################2               |  60%
# libcublas-12.4.5.8   | 247.6 MB  | ##############1                       |  38%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | #############################6        |  80%
#
# pytorch-2.5.1        | 1.46 GB   | ##3                                   |   6%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ######################5               |  61%
# libcublas-12.4.5.8   | 247.6 MB  | ##############3                       |  39%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##############################        |  81%
#
# pytorch-2.5.1        | 1.46 GB   | ##3                                   |   6%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ######################8               |  62%
# libcublas-12.4.5.8   | 247.6 MB  | ##############5                       |  39%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##############################3       |  82%
#
# torchtriton-3.1.0    | 233.6 MB  | ###############6                      |  42%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #######################2              |  63%
# pytorch-2.5.1        | 1.46 GB   | ##4                                   |   7%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##############################6       |  83%
#
# pytorch-2.5.1        | 1.46 GB   | ##4                                   |   7%
# libcublas-12.4.5.8   | 247.6 MB  | ###############                       |  41%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #######################5              |  64%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##############################9       |  84%
#
# pytorch-2.5.1        | 1.46 GB   | ##4                                   |   7%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #######################8              |  64%
# libcublas-12.4.5.8   | 247.6 MB  | ###############2                      |  41%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ###############################3      |  85%
#
# pytorch-2.5.1        | 1.46 GB   | ##5                                   |   7%
# libcublas-12.4.5.8   | 247.6 MB  | ###############5                      |  42%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ########################              |  65%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##5                                   |   7%
#
# torchtriton-3.1.0    | 233.6 MB  | ################4                     |  44%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ########################4             |  66%
# libcublas-12.4.5.8   | 247.6 MB  | ###############7                      |  43%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ################################      |  87%
#
# pytorch-2.5.1        | 1.46 GB   | ##5                                   |   7%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ########################8             |  67%
# libcublas-12.4.5.8   | 247.6 MB  | ################                      |  43%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##6                                   |   7%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #########################1            |  68%
#
# torchtriton-3.1.0    | 233.6 MB  | ################8                     |  45%
# libcublas-12.4.5.8   | 247.6 MB  | ################2                     |  44%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##6                                   |   7%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #########################4            |  69%
#
# torchtriton-3.1.0    | 233.6 MB  | ################9                     |  46%
# libcublas-12.4.5.8   | 247.6 MB  | ################4                     |  44%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##6                                   |   7%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #########################7            |  70%
# libcublas-12.4.5.8   | 247.6 MB  | ################6                     |  45%
#
# torchtriton-3.1.0    | 233.6 MB  | #################1                    |  46%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##7                                   |   7%
# libcublas-12.4.5.8   | 247.6 MB  | ################9                     |  46%
#
# torchtriton-3.1.0    | 233.6 MB  | #################3                    |  47%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##########################            |  70%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##7                                   |   7%
# libcublas-12.4.5.8   | 247.6 MB  | #################2                    |  47%
#
# torchtriton-3.1.0    | 233.6 MB  | #################5                    |  47%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##########################3           |  71%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##7                                   |   8%
#
# torchtriton-3.1.0    | 233.6 MB  | #################7                    |  48%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##########################6           |  72%
# libcublas-12.4.5.8   | 247.6 MB  | #################5                    |  47%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ##################################9   |  95%
#
# pytorch-2.5.1        | 1.46 GB   | ##8                                   |   8%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##########################9           |  73%
# libcublas-12.4.5.8   | 247.6 MB  | #################7                    |  48%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ###################################4  |  96%
#
# pytorch-2.5.1        | 1.46 GB   | ##8                                   |   8%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###########################1          |  74%
# libcublas-12.4.5.8   | 247.6 MB  | #################9                    |  49%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ###################################8  |  97%
#
# pytorch-2.5.1        | 1.46 GB   | ##8                                   |   8%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###########################4          |  74%
# libcublas-12.4.5.8   | 247.6 MB  | ##################2                   |  49%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##9                                   |   8%
#
# torchtriton-3.1.0    | 233.6 MB  | ##################5                   |  50%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###########################8          |  75%
# libcublas-12.4.5.8   | 247.6 MB  | ##################4                   |  50%
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##9                                   |   8%
#
# torchtriton-3.1.0    | 233.6 MB  | ##################8                   |  51%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ############################1         |  76%
# libcublas-12.4.5.8   | 247.6 MB  | ##################6                   |  51%
#
#
#
# libcusparse-12.3.1.1 | 120.0 MB  | ####################################8 | 100%
#
#
# pytorch-2.5.1        | 1.46 GB   | ##9                                   |   8%
#
# torchtriton-3.1.0    | 233.6 MB  | ###################                   |  51%
# pytorch-2.5.1        | 1.46 GB   | ###                                   |   8%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ############################7         |  78%
#
# torchtriton-3.1.0    | 233.6 MB  | ###################2                  |  52%
# pytorch-2.5.1        | 1.46 GB   | ###                                   |   8%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #############################         |  79%
#
# torchtriton-3.1.0    | 233.6 MB  | ###################5                  |  53%
# pytorch-2.5.1        | 1.46 GB   | ###1                                  |   8%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #############################4        |  80%
#
# torchtriton-3.1.0    | 233.6 MB  | ###################8                  |  54%
# pytorch-2.5.1        | 1.46 GB   | ###1                                  |   9%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #############################7        |  80%
#
# torchtriton-3.1.0    | 233.6 MB  | ####################                  |  54%
# pytorch-2.5.1        | 1.46 GB   | ###2                                  |   9%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##############################1       |  81%
#
# torchtriton-3.1.0    | 233.6 MB  | ####################3                 |  55%
# pytorch-2.5.1        | 1.46 GB   | ###2                                  |   9%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##############################4       |  82%
#
# torchtriton-3.1.0    | 233.6 MB  | ####################5                 |  56%
# pytorch-2.5.1        | 1.46 GB   | ###2                                  |   9%
#
# torchtriton-3.1.0    | 233.6 MB  | ####################8                 |  56%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##############################7       |  83%
# pytorch-2.5.1        | 1.46 GB   | ###3                                  |   9%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###############################1      |  84%
#
# torchtriton-3.1.0    | 233.6 MB  | #####################1                |  57%
# pytorch-2.5.1        | 1.46 GB   | ###3                                  |   9%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###############################4      |  85%
#
# torchtriton-3.1.0    | 233.6 MB  | #####################4                |  58%
# pytorch-2.5.1        | 1.46 GB   | ###4                                  |   9%
#
# torchtriton-3.1.0    | 233.6 MB  | #####################6                |  59%
# libcublas-12.4.5.8   | 247.6 MB  | #####################4                |  58%
#
#
# pytorch-2.5.1        | 1.46 GB   | ###4                                  |   9%
# libcublas-12.4.5.8   | 247.6 MB  | #####################7                |  59%
#
# torchtriton-3.1.0    | 233.6 MB  | #####################9                |  59%
#
#
# pytorch-2.5.1        | 1.46 GB   | ###5                                  |   9%
# libcublas-12.4.5.8   | 247.6 MB  | ######################                |  59%
#
# torchtriton-3.1.0    | 233.6 MB  | ######################1               |  60%
#
#
# pytorch-2.5.1        | 1.46 GB   | ###5                                  |  10%
# libcublas-12.4.5.8   | 247.6 MB  | ######################2               |  60%
#
# torchtriton-3.1.0    | 233.6 MB  | ######################4               |  61%
#
#
# pytorch-2.5.1        | 1.46 GB   | ###5                                  |  10%
# libcublas-12.4.5.8   | 247.6 MB  | ######################5               |  61%
#
# torchtriton-3.1.0    | 233.6 MB  | ######################6               |  61%
#
#
# pytorch-2.5.1        | 1.46 GB   | ###6                                  |  10%
# libcublas-12.4.5.8   | 247.6 MB  | ######################7               |  62%
#
# torchtriton-3.1.0    | 233.6 MB  | ######################8               |  62%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #################################5    |  91%
# libcublas-12.4.5.8   | 247.6 MB  | #######################               |  62%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | #################################9    |  92%
#
# pytorch-2.5.1        | 1.46 GB   | ###6                                  |  10%
# libcublas-12.4.5.8   | 247.6 MB  | #######################2              |  63%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##################################3   |  93%
#
# pytorch-2.5.1        | 1.46 GB   | ###7                                  |  10%
# libcublas-12.4.5.8   | 247.6 MB  | #######################5              |  64%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ##################################7   |  94%
#
# pytorch-2.5.1        | 1.46 GB   | ###7                                  |  10%
# libcublas-12.4.5.8   | 247.6 MB  | #######################8              |  64%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###################################   |  95%
#
# pytorch-2.5.1        | 1.46 GB   | ###7                                  |  10%
# libcublas-12.4.5.8   | 247.6 MB  | ########################              |  65%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###################################4  |  96%
#
# pytorch-2.5.1        | 1.46 GB   | ###8                                  |  10%
# libcublas-12.4.5.8   | 247.6 MB  | ########################3             |  66%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ###################################8  |  97%
#
# pytorch-2.5.1        | 1.46 GB   | ###8                                  |  10%
# libcublas-12.4.5.8   | 247.6 MB  | ########################6             |  67%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ####################################1 |  98%
#
# torchtriton-3.1.0    | 233.6 MB  | ########################5             |  66%
# pytorch-2.5.1        | 1.46 GB   | ###8                                  |  11%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ####################################5 |  99%
#
# pytorch-2.5.1        | 1.46 GB   | ###9                                  |  11%
# libcublas-12.4.5.8   | 247.6 MB  | #########################2            |  68%
#
#
# libcufft-11.2.1.3    | 174.5 MB  | ####################################9 | 100%
#
# pytorch-2.5.1        | 1.46 GB   | ###9                                  |  11%
# ...
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | ##################1                   |  49%
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###########8                          |  32%
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###########9                          |  32%
#
# torchtriton-3.1.0    | 233.6 MB  | ##################################### | 100%
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | ######################7               |  62%
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   |                                       |   0%
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###########9                          |  32%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###########9                          |  32%
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | #########################9            |  70%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############                          |  33%
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | ###########################3          |  74%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############                          |  33%
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | ############################7         |  78%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############1                         |  33%
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | #######6                              |  21%
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############1                         |  33%
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | #########6                            |  26%
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############1                         |  33%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############2                         |  33%
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | ################################2     |  87%
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | ##############                        |  38%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############2                         |  33%
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | #################################2    |  90%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############2                         |  33%
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | ##################################1   |  92%
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | ###################9                  |  54%
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############2                         |  33%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############3                         |  33%
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | ####################################  |  97%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############3                         |  33%
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | ####################################9 | 100%
# libcublas-12.4.5.8   | 247.6 MB  | ##################################### | 100%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############3                         |  33%
#
#
#
#
#
#
#
#
# libnvjitlink-12.4.12 | 17.4 MB   |                                       |   0%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############4                         |  34%
#
#
#
#
#
#
#
#
# libnvjitlink-12.4.12 | 17.4 MB   | ###                                   |   8%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############4                         |  34%
#
#
#
#
#
#
#
#
# libnvjitlink-12.4.12 | 17.4 MB   | ######                                |  16%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############4                         |  34%
#
#
#
#
#
#
#
#
# libnvjitlink-12.4.12 | 17.4 MB   | ########8                             |  24%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############5                         |  34%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############5                         |  34%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############5                         |  34%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############6                         |  34%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############6                         |  34%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############6                         |  34%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############7                         |  34%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############7                         |  35%
#
#
#
#
#
#
#
#
# libnvjitlink-12.4.12 | 17.4 MB   | ###################################4  |  96%
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############8                         |  35%
#
#
#
#
#
#
#
#
#
# sympy-1.13.3         | 15.0 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############8                         |  35%
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############8                         |  35%
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############9                         |  35%
#
#
#
#
#
#
#
#
#
# sympy-1.13.3         | 15.0 MB   | ############9                         |  35%
#
#
#
#
#
#
#
# cuda-nvrtc-12.4.127  | 19.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ############9                         |  35%
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############                         |  35%
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############                         |  35%
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############                         |  35%
#
#
#
#
#
#
#
#
#
# sympy-1.13.3         | 15.0 MB   | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############1                        |  35%
#
#
#
#
#
#
#
#
#
# sympy-1.13.3         | 15.0 MB   | ##############################3       |  82%
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############1                        |  36%
#
#
#
#
#
#
#
#
#
# sympy-1.13.3         | 15.0 MB   | #################################4    |  90%
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############1                        |  36%
#
#
#
#
#
#
#
#
#
# sympy-1.13.3         | 15.0 MB   | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ###################################7  |  97%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############2                        |  36%
#
#
# pytorch-2.5.1        | 1.46 GB   | #############3                        |  36%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############3                        |  36%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############4                        |  36%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############4                        |  36%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############5                        |  36%
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.1   | 8.4 MB    | ###################8                  |  54%
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3           | 9.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 6.3 MB    |                                       |   0%
#
#
#
#
#
#
# libcurand-10.3.5.147 | 42.4 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############5                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 6.3 MB    | #####6                                |  15%
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.1   | 8.4 MB    | ################################      |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############5                        |  37%
#
#
#
#
#
#
#
#
#
# sympy-1.13.3         | 15.0 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 6.3 MB    | ###########2                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | ###################4                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 3.1 MB    | 1                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############6                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | ############################8         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 3.1 MB    | #############7                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############6                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 3.1 MB    | ###########################4          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############7                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 3.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-12.3.1.117 | 2.6 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############8                        |  37%
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.1   | 8.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-12.3.1.117 | 2.6 MB    | ###############8                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-cupti-12.4.127  | 2.0 MB    | ######################5               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    | 5                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############8                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 6.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    | ###########################5          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############9                        |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-cupti-12.4.127  | 2.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufile-1.9.1.3    | 995 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufile-1.9.1.3    | 995 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #############9                        |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 821 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-12.3.1.117 | 2.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvfatbin-12.4.127 | 857 KB    | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##############                        |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-2.0.0  | 950 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 821 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 821 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvfatbin-12.4.127 | 857 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###############                       |  41%
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##################2                   |  49%
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ###################5                  |  53%
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ####################6                 |  56%
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | #####################7                |  59%
# pytorch-2.5.1        | 1.46 GB   | ######################6               |  61%
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##############################8       |  83%
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# networkx-3.4.2       | 3.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# llvm-openmp-14.0.6   | 4.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# sympy-1.13.3         | 15.0 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# torchvision-0.20.1   | 8.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gnutls-3.6.15        | 1.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-cupti-12.4.127  | 2.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufile-1.9.1.3    | 995 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.5.1        | 1.46 GB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-2.0.0  | 950 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mpfr-4.2.1           | 821 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvfatbin-12.4.127 | 857 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-2.5.1     | 6.3 MB    | ##################################### | 100%
#
# pytorch-2.5.1        | 1.46 GB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: failed
#
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: /iridisfs/ixsoftware/conda/miniconda-py3
#   uid: 49537
#   gid: 245
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
conda activate shuyanenv
# Out:
# CondaError: Run 'conda init' before 'conda activate'
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
import sys

# %%
import sys
print(sys.executable)
# Out:
# /iridisfs/ixsoftware/conda/miniconda-py3/bin/python

# %%
conda init bash
source ~/.bashrc
conda activate shuyanenv
# Out:
#   Cell In[6], line 1
#     conda init bash
#           ^
# SyntaxError: invalid syntax

# %%
print("1")
# Out:
# 1

# %%
which conda
# Out:
#   Cell In[8], line 1
#     which conda
#           ^
# SyntaxError: invalid syntax

# %%
which python
# Out:
#   Cell In[9], line 1
#     which python
#           ^
# SyntaxError: invalid syntax

# %%
ls
# Out:
# Untitled.ipynb  alpine.sif*

# %%
ls /all
# Out:
# ls: cannot access '/all': No such file or directory
